# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
import os 
import math 
import shutil
import glob

# %%
#count the number of images in the respective classes
ROOT_DIR = "F:/New Dataset - Copy"
number_of_images ={}
for dir in os.listdir(ROOT_DIR):
  number_of_images[dir] =len(os.listdir(os.path.join(ROOT_DIR,dir)))
number_of_images.items()
# Out:
# dict_items([('Test', 2), ('train', 2), ('val', 2)])

# %%
import keras
import tensorflow
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import tensorflow as tf
from tensorflow import keras
from keras.layers import Conv2D, Dropout,Flatten, Dense, BatchNormalization,GlobalAvgPool2D
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator

# %%
## CNN MODEL

model = Sequential()

model.add(Conv2D(filters= 16 , kernel_size= (3,3), activation='relu', input_shape = (50,50,3) ) )
model.add(Conv2D(filters= 36 , kernel_size=(3,3) , activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters= 64 , kernel_size=(3,3) , activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters= 128 , kernel_size=(3,3) , activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate= 0.25))

model.add(Flatten())
model.add(Dense(units=120 , activation= 'relu'))
model.add(Dropout(rate= 0.25))
model.add(Dense(units= 1,activation= 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 16)        448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 36)        5220
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 36)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        20800
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 120)               245880
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 121
# =================================================================
# Total params: 346,325
# Trainable params: 346,325
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer= 'adam', loss= keras.losses.binary_crossentropy, metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint

mc= ModelCheckpoint(monitor="val_accuracy",filepath="./JUNIORmodel.h5", verbose= 1 , save_best_only= True , mode= 'auto' )

cd= [mc]

# %%
def preprocessingImages1(path):
#input :: path
#output : pre processed images'''

  image_data =ImageDataGenerator(zoom_range=0.2,shear_range=0.2,rescale=1/255,horizontal_flip=True)
  image = image_data.flow_from_directory(directory=path,target_size=(50,50),batch_size=32,class_mode='binary')
  return image

# %%
path="F:\\New Dataset - Copy\\train"
train_data = preprocessingImages1(path)
# Out:
# Found 4900 images belonging to 2 classes.

# %%
def preprocessingImages2(path):
#input :: path
#output : pre processed images'''

  image_data =ImageDataGenerator(rescale= 1/255)
  image = image_data.flow_from_directory(directory=path,target_size=(50,50),batch_size=32,class_mode='binary')
  return image

# %%
path="F:\\New Dataset - Copy\\Test"
test_data=preprocessingImages2(path)
# Out:
# Found 1050 images belonging to 2 classes.

# %%
path="F:\\New Dataset - Copy\\val"
val_data=preprocessingImages2(path)
# Out:
# Found 1050 images belonging to 2 classes.

# %%
hs = model.fit(train_data,
                steps_per_epoch=8 ,
                 epochs=100 ,
                  verbose= 1,
                    validation_data= val_data,
                        validation_steps= 16 ,
                         callbacks= cd)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 119s 14s/step - loss: 0.6867 - accuracy: 0.5352 - val_loss: 0.7093 - val_accuracy: 0.5000
#
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to .\JUNIORmodel.h5
# Epoch 2/100
# 8/8 [==============================] - 108s 15s/step - loss: 0.6998 - accuracy: 0.5156 - val_loss: 0.6870 - val_accuracy: 0.6191
#
# Epoch 00002: val_accuracy improved from 0.50000 to 0.61914, saving model to .\JUNIORmodel.h5
# Epoch 3/100
# 8/8 [==============================] - 91s 12s/step - loss: 0.6795 - accuracy: 0.7070 - val_loss: 0.6600 - val_accuracy: 0.7227
#
# Epoch 00003: val_accuracy improved from 0.61914 to 0.72266, saving model to .\JUNIORmodel.h5
# Epoch 4/100
# 8/8 [==============================] - 74s 10s/step - loss: 0.6351 - accuracy: 0.6211 - val_loss: 0.5680 - val_accuracy: 0.8184
#
# Epoch 00004: val_accuracy improved from 0.72266 to 0.81836, saving model to .\JUNIORmodel.h5
# Epoch 5/100
# 8/8 [==============================] - 77s 11s/step - loss: 0.6204 - accuracy: 0.6133 - val_loss: 0.5660 - val_accuracy: 0.6895
#
# Epoch 00005: val_accuracy did not improve from 0.81836
# Epoch 6/100
# 8/8 [==============================] - 81s 11s/step - loss: 0.5389 - accuracy: 0.6914 - val_loss: 0.5299 - val_accuracy: 0.6895
#
# Epoch 00006: val_accuracy did not improve from 0.81836
# Epoch 7/100
# 8/8 [==============================] - 102s 14s/step - loss: 0.4995 - accuracy: 0.7578 - val_loss: 0.4546 - val_accuracy: 0.7891
#
# Epoch 00007: val_accuracy did not improve from 0.81836
# Epoch 8/100
# 8/8 [==============================] - 88s 12s/step - loss: 0.5148 - accuracy: 0.7461 - val_loss: 0.4068 - val_accuracy: 0.7969
#
# Epoch 00008: val_accuracy did not improve from 0.81836
# Epoch 9/100
# 8/8 [==============================] - 81s 11s/step - loss: 0.4375 - accuracy: 0.7930 - val_loss: 0.4274 - val_accuracy: 0.7832
#
# Epoch 00009: val_accuracy did not improve from 0.81836
# Epoch 10/100
# 8/8 [==============================] - 75s 10s/step - loss: 0.4506 - accuracy: 0.7734 - val_loss: 0.3422 - val_accuracy: 0.8438
#
# Epoch 00010: val_accuracy improved from 0.81836 to 0.84375, saving model to .\JUNIORmodel.h5
# Epoch 11/100
# 8/8 [==============================] - 83s 11s/step - loss: 0.3852 - accuracy: 0.8164 - val_loss: 0.3144 - val_accuracy: 0.8867
#
# Epoch 00011: val_accuracy improved from 0.84375 to 0.88672, saving model to .\JUNIORmodel.h5
# Epoch 12/100
# 8/8 [==============================] - 129s 17s/step - loss: 0.4138 - accuracy: 0.8047 - val_loss: 0.3462 - val_accuracy: 0.8379
#
# Epoch 00012: val_accuracy did not improve from 0.88672
# Epoch 13/100
# 8/8 [==============================] - 80s 11s/step - loss: 0.3221 - accuracy: 0.8672 - val_loss: 0.3211 - val_accuracy: 0.8477
#
# Epoch 00013: val_accuracy did not improve from 0.88672
# Epoch 14/100
# 8/8 [==============================] - 123s 17s/step - loss: 0.3005 - accuracy: 0.8789 - val_loss: 0.2532 - val_accuracy: 0.9043
#
# Epoch 00014: val_accuracy improved from 0.88672 to 0.90430, saving model to .\JUNIORmodel.h5
# Epoch 15/100
# 8/8 [==============================] - 96s 13s/step - loss: 0.3101 - accuracy: 0.9035 - val_loss: 0.3004 - val_accuracy: 0.8594
#
# Epoch 00015: val_accuracy did not improve from 0.90430
# Epoch 16/100
# 8/8 [==============================] - 90s 12s/step - loss: 0.2888 - accuracy: 0.8906 - val_loss: 0.2646 - val_accuracy: 0.8945
#
# Epoch 00016: val_accuracy did not improve from 0.90430
# Epoch 17/100
# 8/8 [==============================] - 78s 11s/step - loss: 0.3299 - accuracy: 0.8633 - val_loss: 0.3055 - val_accuracy: 0.8535
#
# Epoch 00017: val_accuracy did not improve from 0.90430
# Epoch 18/100
# 8/8 [==============================] - 74s 10s/step - loss: 0.3975 - accuracy: 0.8203 - val_loss: 0.2622 - val_accuracy: 0.9082
#
# Epoch 00018: val_accuracy improved from 0.90430 to 0.90820, saving model to .\JUNIORmodel.h5
# Epoch 19/100
# 8/8 [==============================] - 97s 13s/step - loss: 0.3242 - accuracy: 0.8516 - val_loss: 0.2593 - val_accuracy: 0.8945
#
# Epoch 00019: val_accuracy did not improve from 0.90820
# Epoch 20/100
# 8/8 [==============================] - 97s 13s/step - loss: 0.3513 - accuracy: 0.8594 - val_loss: 0.2868 - val_accuracy: 0.8770
#
# Epoch 00020: val_accuracy did not improve from 0.90820
# Epoch 21/100
# 8/8 [==============================] - 86s 12s/step - loss: 0.2736 - accuracy: 0.8945 - val_loss: 0.3178 - val_accuracy: 0.8594
#
# Epoch 00021: val_accuracy did not improve from 0.90820
# Epoch 22/100
# 8/8 [==============================] - 82s 11s/step - loss: 0.3363 - accuracy: 0.8398 - val_loss: 0.3245 - val_accuracy: 0.8691
#
# Epoch 00022: val_accuracy did not improve from 0.90820
# Epoch 23/100
# 8/8 [==============================] - 93s 13s/step - loss: 0.3206 - accuracy: 0.8672 - val_loss: 0.2713 - val_accuracy: 0.8984
#
# Epoch 00023: val_accuracy did not improve from 0.90820
# Epoch 24/100
# 8/8 [==============================] - 106s 14s/step - loss: 0.3001 - accuracy: 0.8750 - val_loss: 0.3098 - val_accuracy: 0.8652
#
# Epoch 00024: val_accuracy did not improve from 0.90820
# Epoch 25/100
# 8/8 [==============================] - 101s 14s/step - loss: 0.2854 - accuracy: 0.8672 - val_loss: 0.3155 - val_accuracy: 0.8555
#
# Epoch 00025: val_accuracy did not improve from 0.90820
# Epoch 26/100
# 8/8 [==============================] - 85s 11s/step - loss: 0.4086 - accuracy: 0.8203 - val_loss: 0.5132 - val_accuracy: 0.7598
#
# Epoch 00026: val_accuracy did not improve from 0.90820
# Epoch 27/100
# 8/8 [==============================] - 74s 10s/step - loss: 0.3550 - accuracy: 0.8438 - val_loss: 0.3238 - val_accuracy: 0.8301
#
# Epoch 00027: val_accuracy did not improve from 0.90820
# Epoch 28/100
# 8/8 [==============================] - 201s 28s/step - loss: 0.3089 - accuracy: 0.8516 - val_loss: 0.2754 - val_accuracy: 0.8984
#
# Epoch 00028: val_accuracy did not improve from 0.90820
# Epoch 29/100
# 8/8 [==============================] - 94s 13s/step - loss: 0.3257 - accuracy: 0.8750 - val_loss: 0.2922 - val_accuracy: 0.8789
#
# Epoch 00029: val_accuracy did not improve from 0.90820
# Epoch 30/100
# 8/8 [==============================] - 77s 10s/step - loss: 0.3770 - accuracy: 0.8421 - val_loss: 0.2822 - val_accuracy: 0.8789
#
# Epoch 00030: val_accuracy did not improve from 0.90820
# Epoch 31/100
# 8/8 [==============================] - 79s 11s/step - loss: 0.2703 - accuracy: 0.8867 - val_loss: 0.2307 - val_accuracy: 0.9121
#
# Epoch 00031: val_accuracy improved from 0.90820 to 0.91211, saving model to .\JUNIORmodel.h5
# Epoch 32/100
# 8/8 [==============================] - 83s 11s/step - loss: 0.2928 - accuracy: 0.8750 - val_loss: 0.2495 - val_accuracy: 0.8965
#
# Epoch 00032: val_accuracy did not improve from 0.91211
# Epoch 33/100
# 8/8 [==============================] - 76s 10s/step - loss: 0.3151 - accuracy: 0.8672 - val_loss: 0.4467 - val_accuracy: 0.7559
#
# Epoch 00033: val_accuracy did not improve from 0.91211
# Epoch 34/100
# 8/8 [==============================] - 81s 11s/step - loss: 0.3004 - accuracy: 0.8633 - val_loss: 0.3917 - val_accuracy: 0.8418
#
# Epoch 00034: val_accuracy did not improve from 0.91211
# Epoch 35/100
# 8/8 [==============================] - 71s 10s/step - loss: 0.3408 - accuracy: 0.8516 - val_loss: 0.2702 - val_accuracy: 0.8809
#
# Epoch 00035: val_accuracy did not improve from 0.91211
# Epoch 36/100
# 8/8 [==============================] - 74s 10s/step - loss: 0.2737 - accuracy: 0.8867 - val_loss: 0.2608 - val_accuracy: 0.9023
#
# Epoch 00036: val_accuracy did not improve from 0.91211
# Epoch 37/100
# 8/8 [==============================] - 71s 10s/step - loss: 0.2497 - accuracy: 0.8906 - val_loss: 0.2522 - val_accuracy: 0.9023
#
# Epoch 00037: val_accuracy did not improve from 0.91211
# Epoch 38/100
# 8/8 [==============================] - 72s 10s/step - loss: 0.2683 - accuracy: 0.9023 - val_loss: 0.2259 - val_accuracy: 0.9238
#
# Epoch 00038: val_accuracy improved from 0.91211 to 0.92383, saving model to .\JUNIORmodel.h5
# Epoch 39/100
# 8/8 [==============================] - 73s 10s/step - loss: 0.3005 - accuracy: 0.8555 - val_loss: 0.2090 - val_accuracy: 0.9453
#
# Epoch 00039: val_accuracy improved from 0.92383 to 0.94531, saving model to .\JUNIORmodel.h5
# Epoch 40/100
# 8/8 [==============================] - 74s 10s/step - loss: 0.2624 - accuracy: 0.8984 - val_loss: 0.2377 - val_accuracy: 0.9199
#
# Epoch 00040: val_accuracy did not improve from 0.94531
# Epoch 41/100
# 8/8 [==============================] - 73s 10s/step - loss: 0.2914 - accuracy: 0.8828 - val_loss: 0.2210 - val_accuracy: 0.9316
#
# Epoch 00041: val_accuracy did not improve from 0.94531
# Epoch 42/100
# 8/8 [==============================] - 79s 11s/step - loss: 0.2134 - accuracy: 0.9141 - val_loss: 0.1955 - val_accuracy: 0.9336
#
# Epoch 00042: val_accuracy did not improve from 0.94531
# Epoch 43/100
# 8/8 [==============================] - 72s 10s/step - loss: 0.2657 - accuracy: 0.9102 - val_loss: 0.2127 - val_accuracy: 0.9160
#
# Epoch 00043: val_accuracy did not improve from 0.94531
# Epoch 44/100
# 8/8 [==============================] - 69s 9s/step - loss: 0.3033 - accuracy: 0.8750 - val_loss: 0.2134 - val_accuracy: 0.9316
#
# Epoch 00044: val_accuracy did not improve from 0.94531
# Epoch 45/100
# 8/8 [==============================] - 80s 11s/step - loss: 0.2538 - accuracy: 0.9062 - val_loss: 0.1966 - val_accuracy: 0.9297
#
# Epoch 00045: val_accuracy did not improve from 0.94531
# Epoch 46/100
# 8/8 [==============================] - 66s 9s/step - loss: 0.2437 - accuracy: 0.8984 - val_loss: 0.2095 - val_accuracy: 0.9199
#
# Epoch 00046: val_accuracy did not improve from 0.94531
# Epoch 47/100
# 8/8 [==============================] - 69s 9s/step - loss: 0.3073 - accuracy: 0.8828 - val_loss: 0.2964 - val_accuracy: 0.8809
#
# Epoch 00047: val_accuracy did not improve from 0.94531
# Epoch 48/100
# 8/8 [==============================] - 70s 10s/step - loss: 0.2757 - accuracy: 0.8633 - val_loss: 0.2464 - val_accuracy: 0.9004
#
# Epoch 00048: val_accuracy did not improve from 0.94531
# Epoch 49/100
# 8/8 [==============================] - 82s 11s/step - loss: 0.3121 - accuracy: 0.8672 - val_loss: 0.2179 - val_accuracy: 0.9277
#
# Epoch 00049: val_accuracy did not improve from 0.94531
# Epoch 50/100
# 8/8 [==============================] - 73s 10s/step - loss: 0.3230 - accuracy: 0.8477 - val_loss: 0.2296 - val_accuracy: 0.9180
#
# Epoch 00050: val_accuracy did not improve from 0.94531
# Epoch 51/100
# 8/8 [==============================] - 132s 18s/step - loss: 0.3427 - accuracy: 0.8711 - val_loss: 0.2479 - val_accuracy: 0.9062
#
# Epoch 00051: val_accuracy did not improve from 0.94531
# Epoch 52/100
# 8/8 [==============================] - 104s 14s/step - loss: 0.2477 - accuracy: 0.9023 - val_loss: 0.2064 - val_accuracy: 0.9219
#
# Epoch 00052: val_accuracy did not improve from 0.94531
# Epoch 53/100
# 8/8 [==============================] - 78s 11s/step - loss: 0.2800 - accuracy: 0.9062 - val_loss: 0.2173 - val_accuracy: 0.9219
#
# Epoch 00053: val_accuracy did not improve from 0.94531
# Epoch 54/100
# 8/8 [==============================] - 79s 11s/step - loss: 0.2584 - accuracy: 0.8945 - val_loss: 0.2003 - val_accuracy: 0.9141
#
# Epoch 00054: val_accuracy did not improve from 0.94531
# Epoch 55/100
# 8/8 [==============================] - 87s 12s/step - loss: 0.3175 - accuracy: 0.8640 - val_loss: 0.2019 - val_accuracy: 0.9277
#
# Epoch 00055: val_accuracy did not improve from 0.94531
# Epoch 56/100
# 8/8 [==============================] - 91s 13s/step - loss: 0.2631 - accuracy: 0.9141 - val_loss: 0.2053 - val_accuracy: 0.9277
#
# Epoch 00056: val_accuracy did not improve from 0.94531
# Epoch 57/100
# 8/8 [==============================] - 63s 9s/step - loss: 0.2150 - accuracy: 0.9180 - val_loss: 0.2150 - val_accuracy: 0.9023
#
# Epoch 00057: val_accuracy did not improve from 0.94531
# Epoch 58/100
# 8/8 [==============================] - 65s 9s/step - loss: 0.2343 - accuracy: 0.9062 - val_loss: 0.1890 - val_accuracy: 0.9375
#
# Epoch 00058: val_accuracy did not improve from 0.94531
# Epoch 59/100
# 8/8 [==============================] - 73s 10s/step - loss: 0.3008 - accuracy: 0.9023 - val_loss: 0.2329 - val_accuracy: 0.9043
#
# Epoch 00059: val_accuracy did not improve from 0.94531
# Epoch 60/100
# 8/8 [==============================] - 71s 10s/step - loss: 0.1821 - accuracy: 0.9492 - val_loss: 0.2162 - val_accuracy: 0.9141
#
# Epoch 00060: val_accuracy did not improve from 0.94531
# Epoch 61/100
# 8/8 [==============================] - 79s 11s/step - loss: 0.2222 - accuracy: 0.8984 - val_loss: 0.1844 - val_accuracy: 0.9395
#
# Epoch 00061: val_accuracy did not improve from 0.94531
# Epoch 62/100
# 8/8 [==============================] - 76s 10s/step - loss: 0.2964 - accuracy: 0.8672 - val_loss: 0.2106 - val_accuracy: 0.9219
#
# Epoch 00062: val_accuracy did not improve from 0.94531
# Epoch 63/100
# 8/8 [==============================] - 86s 12s/step - loss: 0.2437 - accuracy: 0.9102 - val_loss: 0.1791 - val_accuracy: 0.9258
#
# Epoch 00063: val_accuracy did not improve from 0.94531
# Epoch 64/100
# 8/8 [==============================] - 88s 12s/step - loss: 0.2667 - accuracy: 0.9062 - val_loss: 0.2115 - val_accuracy: 0.9102
#
# Epoch 00064: val_accuracy did not improve from 0.94531
# Epoch 65/100
# 8/8 [==============================] - 67s 9s/step - loss: 0.2432 - accuracy: 0.8945 - val_loss: 0.2190 - val_accuracy: 0.9199
#
# Epoch 00065: val_accuracy did not improve from 0.94531
# Epoch 66/100
# 8/8 [==============================] - 81s 11s/step - loss: 0.2620 - accuracy: 0.8984 - val_loss: 0.2690 - val_accuracy: 0.8750
#
# Epoch 00066: val_accuracy did not improve from 0.94531
# Epoch 67/100
# 8/8 [==============================] - 96s 13s/step - loss: 0.2577 - accuracy: 0.9180 - val_loss: 0.2152 - val_accuracy: 0.9180
#
# Epoch 00067: val_accuracy did not improve from 0.94531
# Epoch 68/100
# 8/8 [==============================] - 82s 11s/step - loss: 0.3130 - accuracy: 0.8594 - val_loss: 0.2091 - val_accuracy: 0.9375
#
# Epoch 00068: val_accuracy did not improve from 0.94531
# Epoch 69/100
# 8/8 [==============================] - 63s 9s/step - loss: 0.2399 - accuracy: 0.9258 - val_loss: 0.1757 - val_accuracy: 0.9453
#
# Epoch 00069: val_accuracy did not improve from 0.94531
# Epoch 70/100
# 8/8 [==============================] - 64s 9s/step - loss: 0.1979 - accuracy: 0.9258 - val_loss: 0.1725 - val_accuracy: 0.9473
#
# Epoch 00070: val_accuracy improved from 0.94531 to 0.94727, saving model to .\JUNIORmodel.h5
# Epoch 71/100
# 8/8 [==============================] - 67s 9s/step - loss: 0.2767 - accuracy: 0.8828 - val_loss: 0.2171 - val_accuracy: 0.9121
#
# Epoch 00071: val_accuracy did not improve from 0.94727
# Epoch 72/100
# 8/8 [==============================] - 58s 7s/step - loss: 0.2647 - accuracy: 0.8789 - val_loss: 0.2571 - val_accuracy: 0.9004
#
# Epoch 00072: val_accuracy did not improve from 0.94727
# Epoch 73/100
# 8/8 [==============================] - 57s 8s/step - loss: 0.2445 - accuracy: 0.8984 - val_loss: 0.2038 - val_accuracy: 0.9414
#
# Epoch 00073: val_accuracy did not improve from 0.94727
# Epoch 74/100
# 8/8 [==============================] - 57s 8s/step - loss: 0.2733 - accuracy: 0.8984 - val_loss: 0.2203 - val_accuracy: 0.9219
#
# Epoch 00074: val_accuracy did not improve from 0.94727
# Epoch 75/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2637 - accuracy: 0.8789 - val_loss: 0.2038 - val_accuracy: 0.9238
#
# Epoch 00075: val_accuracy did not improve from 0.94727
# Epoch 76/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.2347 - accuracy: 0.8984 - val_loss: 0.2655 - val_accuracy: 0.8926
#
# Epoch 00076: val_accuracy did not improve from 0.94727
# Epoch 77/100
# 8/8 [==============================] - 65s 9s/step - loss: 0.1926 - accuracy: 0.9141 - val_loss: 0.1977 - val_accuracy: 0.9414
#
# Epoch 00077: val_accuracy did not improve from 0.94727
# Epoch 78/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.2275 - accuracy: 0.9141 - val_loss: 0.1927 - val_accuracy: 0.9316
#
# Epoch 00078: val_accuracy did not improve from 0.94727
# Epoch 79/100
# 8/8 [==============================] - 61s 8s/step - loss: 0.2236 - accuracy: 0.9211 - val_loss: 0.2614 - val_accuracy: 0.9043
#
# Epoch 00079: val_accuracy did not improve from 0.94727
# Epoch 80/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.2474 - accuracy: 0.8984 - val_loss: 0.2250 - val_accuracy: 0.9316
#
# Epoch 00080: val_accuracy did not improve from 0.94727
# Epoch 81/100
# 8/8 [==============================] - 56s 7s/step - loss: 0.2513 - accuracy: 0.8906 - val_loss: 0.1791 - val_accuracy: 0.9453
#
# Epoch 00081: val_accuracy did not improve from 0.94727
# Epoch 82/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.1967 - accuracy: 0.9297 - val_loss: 0.2189 - val_accuracy: 0.9141
#
# Epoch 00082: val_accuracy did not improve from 0.94727
# Epoch 83/100
# 8/8 [==============================] - 55s 7s/step - loss: 0.2424 - accuracy: 0.8984 - val_loss: 0.3289 - val_accuracy: 0.8379
#
# Epoch 00083: val_accuracy did not improve from 0.94727
# Epoch 84/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.2336 - accuracy: 0.9180 - val_loss: 0.2006 - val_accuracy: 0.9199
#
# Epoch 00084: val_accuracy did not improve from 0.94727
# Epoch 85/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.2675 - accuracy: 0.8984 - val_loss: 0.1803 - val_accuracy: 0.9395
#
# Epoch 00085: val_accuracy did not improve from 0.94727
# Epoch 86/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.2941 - accuracy: 0.8984 - val_loss: 0.2036 - val_accuracy: 0.9375
#
# Epoch 00086: val_accuracy did not improve from 0.94727
# Epoch 87/100
# 8/8 [==============================] - 57s 8s/step - loss: 0.3131 - accuracy: 0.8516 - val_loss: 0.1839 - val_accuracy: 0.9297
#
# Epoch 00087: val_accuracy did not improve from 0.94727
# Epoch 88/100
# 8/8 [==============================] - 65s 9s/step - loss: 0.2098 - accuracy: 0.9258 - val_loss: 0.1749 - val_accuracy: 0.9414
#
# Epoch 00088: val_accuracy did not improve from 0.94727
# Epoch 89/100
# 8/8 [==============================] - 127s 18s/step - loss: 0.1993 - accuracy: 0.9219 - val_loss: 0.1900 - val_accuracy: 0.9414
#
# Epoch 00089: val_accuracy did not improve from 0.94727
# Epoch 90/100
# 8/8 [==============================] - 67s 9s/step - loss: 0.2689 - accuracy: 0.9023 - val_loss: 0.2227 - val_accuracy: 0.9219
#
# Epoch 00090: val_accuracy did not improve from 0.94727
# Epoch 91/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2749 - accuracy: 0.8945 - val_loss: 0.2372 - val_accuracy: 0.9121
#
# Epoch 00091: val_accuracy did not improve from 0.94727
# Epoch 92/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2390 - accuracy: 0.9297 - val_loss: 0.2087 - val_accuracy: 0.9102
#
# Epoch 00092: val_accuracy did not improve from 0.94727
# Epoch 93/100
# 8/8 [==============================] - 62s 8s/step - loss: 0.2737 - accuracy: 0.8906 - val_loss: 0.1865 - val_accuracy: 0.9297
#
# Epoch 00093: val_accuracy did not improve from 0.94727
# Epoch 94/100
# 8/8 [==============================] - 60s 8s/step - loss: 0.2162 - accuracy: 0.9219 - val_loss: 0.1618 - val_accuracy: 0.9316
#
# Epoch 00094: val_accuracy did not improve from 0.94727
# Epoch 95/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.1896 - accuracy: 0.9180 - val_loss: 0.1770 - val_accuracy: 0.9277
#
# Epoch 00095: val_accuracy did not improve from 0.94727
# Epoch 96/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.2046 - accuracy: 0.9258 - val_loss: 0.1552 - val_accuracy: 0.9492
#
# Epoch 00096: val_accuracy improved from 0.94727 to 0.94922, saving model to .\JUNIORmodel.h5
# Epoch 97/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.1456 - accuracy: 0.9492 - val_loss: 0.2515 - val_accuracy: 0.9219
#
# Epoch 00097: val_accuracy did not improve from 0.94922
# Epoch 98/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2077 - accuracy: 0.9258 - val_loss: 0.1588 - val_accuracy: 0.9355
#
# Epoch 00098: val_accuracy did not improve from 0.94922
# Epoch 99/100
# 8/8 [==============================] - 54s 7s/step - loss: 0.1856 - accuracy: 0.9375 - val_loss: 0.1515 - val_accuracy: 0.9609
#
# Epoch 00099: val_accuracy improved from 0.94922 to 0.96094, saving model to .\JUNIORmodel.h5
# Epoch 100/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.2346 - accuracy: 0.8906 - val_loss: 0.1293 - val_accuracy: 0.9473
#
# Epoch 00100: val_accuracy did not improve from 0.96094

# %%
h = hs.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'])

plt.title("acc vs val-acc")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(h['loss'])
plt.plot(h['val_loss'], c= "red")

plt.title("loss vs val-loss")
plt.show()

# %%
  # model accuracy

from keras.models import load_model

model = load_model("C:\\Users\\yuvra\\pyton project\\Untitled Folder\\JUNIORmodel.h5")

# %%
acc = model.evaluate_generator(test_data)[1]

print(f"the accuracy of our model is {acc*100} % ")
# Out:
# the accuracy of our model is 90.0952398777008 %

# %%
from keras.preprocessing.image import load_img, img_to_array

# %%
path="F:\\New Dataset - Copy\\val\\TB\\CHNCXR_0379_1.png"

img = load_img(path, target_size = (50,50))
input_arr = img_to_array(img)/255

input_arr.shape
# Out:
# (50, 50, 3)

# %%
input_arr = np.expand_dims(input_arr, axis= 0 )

# %%
pred1=(model.predict(input_arr))
a= 1-pred1

if (a<pred1):
  print("the image is infected")
else:
  print("the image is healthy")
# Out:
# the image is infected

# %%
  # to display image

plt.imshow(input_arr[0])
plt.title("input image")
plt.show()

# %%
print (pred1)
print("pred is ",pred1)
a= 1-pred1

if (a<pred1):
  print("the image is infected")
else:
  print("the image is healthy")
# Out:
# [[0.96022767]]
# pred is  [[0.96022767]]
# the image is infected

# %%
os.chdir("F:\\New Dataset - Copy\\Test\\TB\\")

# %%
arr=[]
path1=os.listdir()
path1=(path1)
l=len(path1)
print(path1[2])
# Out:
# CHNCXR_0336_1 - Copy.png

# %%
for i in range(0,l):
    path="F:\\New Dataset - Copy\\Test\\TB\\"+path1[i]

    img = load_img(path, target_size = (50,50))
    input_arr = img_to_array(img)/255

    input_arr.shape
    input_arr = np.expand_dims(input_arr, axis= 0 )
    
    pred1=(model.predict(input_arr))
    a= 1-pred1

    if (a<pred1):
      print("Infected")
    else:
      print("Healthy")

    i+1
# Out:
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected

# %%
os.chdir("F:\\New Dataset - Copy\\Test\\Normal\\")

# %%
arr=[]
path1=os.listdir()
path1=(path1)
l=len(path1)
print(path1[2])
# Out:
# Normal-1010.png

# %%
for i in range(0,l):
    path="F:\\New Dataset - Copy\\Test\\Normal\\"+path1[i]

    img = load_img(path, target_size = (50,50))
    input_arr = img_to_array(img)/255

    input_arr.shape
    input_arr = np.expand_dims(input_arr, axis= 0 )
    
    pred1=(model.predict(input_arr))
    a= 1-pred1

    if (a<pred1):
      print("Infected")
    else:
      print("Healthy")

    i+1
# Out:
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import classification_report

# %%
Model_pred=pd.read_excel("C:\\Users\\yuvra\\Documents\\444 proposed model 4 CSV File.xlsx")

# %%
confusion_M1 = pd.crosstab(Model_pred.PREDICTION_CLASS,Model_pred.ACTUAL_CLASS)

# %%
fig = plt.figure(figsize=(17,5))
ax1 = plt.subplot(121)
sn.heatmap(confusion_M1,annot=True,cmap='Blues')
ax1.set_title("Model1")
# Out:
# Text(0.5, 1.0, 'Model1')

# %%
for i in range(confusion_M1.shape[0]):
    TP = confusion_M1.iloc[i,i]
    FP = confusion_M1.iloc[i,:].sum()-TP
    FN = confusion_M1.iloc[:,i].sum()-TP
    TN=confusion_M1.sum().sum()-TP-FP-FN
    Accuracy =(TP+TN)/confusion_M1.sum().sum()
    Precision=TP/(TP+FP)
    Recall=TP/(TP+FN)
    F1_Score =(2 * Precision * Recall)/(Precision+Recall)
    
    print(confusion_M1.index[i],Accuracy,Precision,Recall,F1_Score)
# Out:
# Healthy 0.900952380952381 0.8648180242634316 0.9504761904761905 0.9056261343012705
# Infected 0.900952380952381 0.945031712473573 0.8514285714285714 0.8957915831663328
