# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt
import os 
import math 
import shutil
import glob

# %%
#count the number of images in the respective classes
ROOT_DIR = "F:/New Dataset - Copy"
number_of_images ={}
for dir in os.listdir(ROOT_DIR):
  number_of_images[dir] =len(os.listdir(os.path.join(ROOT_DIR,dir)))
number_of_images.items()
# Out:
# dict_items([('Test', 2), ('train', 2), ('val', 2)])

# %%
import keras
import tensorflow
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import tensorflow as tf
from tensorflow import keras
from keras.layers import Conv2D, Dropout,Flatten, Dense, BatchNormalization,GlobalAvgPool2D
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator

# %%
## CNN MODEL

model = Sequential()

model.add(Conv2D(filters= 16 , kernel_size= (3,3), activation='relu', input_shape = (50,50,3) ) )
model.add(Conv2D(filters= 36 , kernel_size=(3,3) , activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters= 64 , kernel_size=(3,3) , activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate= 0.25))

model.add(Flatten())
model.add(Dense(units=64 , activation= 'relu'))
model.add(Dropout(rate= 0.25))
model.add(Dense(units= 1,activation= 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 16)        448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 36)        5220
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 36)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        20800
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                409664
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 436,197
# Trainable params: 436,197
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer= 'adam', loss= keras.losses.binary_crossentropy, metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint

mc= ModelCheckpoint(monitor="val_accuracy",filepath="./KORESmodel.h5", verbose= 1 , save_best_only= True , mode= 'auto' )

cd= [mc]

# %%
def preprocessingImages1(path):
#input :: path
#output : pre processed images'''

  image_data =ImageDataGenerator(zoom_range=0.2,shear_range=0.2,rescale=1/255,horizontal_flip=True)
  image = image_data.flow_from_directory(directory=path,target_size=(50,50),batch_size=32,class_mode='binary')
  return image

# %%
path="F:\\New Dataset - Copy\\train"
train_data = preprocessingImages1(path)
# Out:
# Found 4900 images belonging to 2 classes.

# %%
def preprocessingImages2(path):
#input :: path
#output : pre processed images'''

  image_data =ImageDataGenerator(rescale= 1/255)
  image = image_data.flow_from_directory(directory=path,target_size=(50,50),batch_size=32,class_mode='binary')
  return image

# %%
path="F:\\New Dataset - Copy\\Test"
test_data=preprocessingImages2(path)
# Out:
# Found 1050 images belonging to 2 classes.

# %%
path="F:\\New Dataset - Copy\\val"
val_data=preprocessingImages2(path)
# Out:
# Found 1050 images belonging to 2 classes.

# %%
hs = model.fit(train_data,
                steps_per_epoch=8 ,
                 epochs=100 ,
                  verbose= 1,
                    validation_data= val_data,
                        validation_steps= 16 ,
                         callbacks= cd)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 163s 21s/step - loss: 0.6897 - accuracy: 0.5547 - val_loss: 0.6731 - val_accuracy: 0.4980
#
# Epoch 00001: val_accuracy improved from -inf to 0.49805, saving model to .\KORESmodel.h5
# Epoch 2/100
# 8/8 [==============================] - 178s 24s/step - loss: 0.6699 - accuracy: 0.5820 - val_loss: 0.6246 - val_accuracy: 0.7461
#
# Epoch 00002: val_accuracy improved from 0.49805 to 0.74609, saving model to .\KORESmodel.h5
# Epoch 3/100
# 8/8 [==============================] - 137s 19s/step - loss: 0.6268 - accuracy: 0.6406 - val_loss: 0.5872 - val_accuracy: 0.6133
#
# Epoch 00003: val_accuracy did not improve from 0.74609
# Epoch 4/100
# 8/8 [==============================] - 79s 10s/step - loss: 0.6006 - accuracy: 0.6404 - val_loss: 0.5117 - val_accuracy: 0.7637
#
# Epoch 00004: val_accuracy improved from 0.74609 to 0.76367, saving model to .\KORESmodel.h5
# Epoch 5/100
# 8/8 [==============================] - 101s 14s/step - loss: 0.4800 - accuracy: 0.7891 - val_loss: 0.4223 - val_accuracy: 0.8457
#
# Epoch 00005: val_accuracy improved from 0.76367 to 0.84570, saving model to .\KORESmodel.h5
# Epoch 6/100
# 8/8 [==============================] - 117s 16s/step - loss: 0.5230 - accuracy: 0.7305 - val_loss: 0.3990 - val_accuracy: 0.8496
#
# Epoch 00006: val_accuracy improved from 0.84570 to 0.84961, saving model to .\KORESmodel.h5
# Epoch 7/100
# 8/8 [==============================] - 90s 12s/step - loss: 0.4221 - accuracy: 0.8320 - val_loss: 0.3578 - val_accuracy: 0.8633
#
# Epoch 00007: val_accuracy improved from 0.84961 to 0.86328, saving model to .\KORESmodel.h5
# Epoch 8/100
# 8/8 [==============================] - 84s 11s/step - loss: 0.4313 - accuracy: 0.8242 - val_loss: 0.3499 - val_accuracy: 0.8574
#
# Epoch 00008: val_accuracy did not improve from 0.86328
# Epoch 9/100
# 8/8 [==============================] - 86s 11s/step - loss: 0.5088 - accuracy: 0.7656 - val_loss: 0.4361 - val_accuracy: 0.8594
#
# Epoch 00009: val_accuracy did not improve from 0.86328
# Epoch 10/100
# 8/8 [==============================] - 92s 12s/step - loss: 0.4571 - accuracy: 0.8359 - val_loss: 0.3539 - val_accuracy: 0.8457
#
# Epoch 00010: val_accuracy did not improve from 0.86328
# Epoch 11/100
# 8/8 [==============================] - 85s 12s/step - loss: 0.4455 - accuracy: 0.8086 - val_loss: 0.3941 - val_accuracy: 0.8262
#
# Epoch 00011: val_accuracy did not improve from 0.86328
# Epoch 12/100
# 8/8 [==============================] - 84s 11s/step - loss: 0.4318 - accuracy: 0.8320 - val_loss: 0.3910 - val_accuracy: 0.8301
#
# Epoch 00012: val_accuracy did not improve from 0.86328
# Epoch 13/100
# 8/8 [==============================] - 81s 11s/step - loss: 0.3414 - accuracy: 0.8398 - val_loss: 0.2937 - val_accuracy: 0.8750
#
# Epoch 00013: val_accuracy improved from 0.86328 to 0.87500, saving model to .\KORESmodel.h5
# Epoch 14/100
# 8/8 [==============================] - 82s 11s/step - loss: 0.3467 - accuracy: 0.8789 - val_loss: 0.3231 - val_accuracy: 0.8574
#
# Epoch 00014: val_accuracy did not improve from 0.87500
# Epoch 15/100
# 8/8 [==============================] - 80s 11s/step - loss: 0.3803 - accuracy: 0.8438 - val_loss: 0.3018 - val_accuracy: 0.8848
#
# Epoch 00015: val_accuracy improved from 0.87500 to 0.88477, saving model to .\KORESmodel.h5
# Epoch 16/100
# 8/8 [==============================] - 86s 12s/step - loss: 0.3614 - accuracy: 0.8438 - val_loss: 0.2848 - val_accuracy: 0.8965
#
# Epoch 00016: val_accuracy improved from 0.88477 to 0.89648, saving model to .\KORESmodel.h5
# Epoch 17/100
# 8/8 [==============================] - 98s 13s/step - loss: 0.3965 - accuracy: 0.8281 - val_loss: 0.3187 - val_accuracy: 0.8711
#
# Epoch 00017: val_accuracy did not improve from 0.89648
# Epoch 18/100
# 8/8 [==============================] - 79s 11s/step - loss: 0.3798 - accuracy: 0.8633 - val_loss: 0.3063 - val_accuracy: 0.8789
#
# Epoch 00018: val_accuracy did not improve from 0.89648
# Epoch 19/100
# 8/8 [==============================] - 77s 10s/step - loss: 0.3744 - accuracy: 0.8359 - val_loss: 0.2862 - val_accuracy: 0.8867
#
# Epoch 00019: val_accuracy did not improve from 0.89648
# Epoch 20/100
# 8/8 [==============================] - 73s 10s/step - loss: 0.3486 - accuracy: 0.8553 - val_loss: 0.3490 - val_accuracy: 0.8359
#
# Epoch 00020: val_accuracy did not improve from 0.89648
# Epoch 21/100
# 8/8 [==============================] - 76s 10s/step - loss: 0.3783 - accuracy: 0.8516 - val_loss: 0.3097 - val_accuracy: 0.8789
#
# Epoch 00021: val_accuracy did not improve from 0.89648
# Epoch 22/100
# 8/8 [==============================] - 74s 10s/step - loss: 0.3765 - accuracy: 0.8477 - val_loss: 0.2779 - val_accuracy: 0.8906
#
# Epoch 00022: val_accuracy did not improve from 0.89648
# Epoch 23/100
# 8/8 [==============================] - 116s 16s/step - loss: 0.3744 - accuracy: 0.8438 - val_loss: 0.3058 - val_accuracy: 0.8691
#
# Epoch 00023: val_accuracy did not improve from 0.89648
# Epoch 24/100
# 8/8 [==============================] - 86s 12s/step - loss: 0.3373 - accuracy: 0.8516 - val_loss: 0.2654 - val_accuracy: 0.8984
#
# Epoch 00024: val_accuracy improved from 0.89648 to 0.89844, saving model to .\KORESmodel.h5
# Epoch 25/100
# 8/8 [==============================] - 76s 10s/step - loss: 0.2784 - accuracy: 0.9062 - val_loss: 0.2829 - val_accuracy: 0.8789
#
# Epoch 00025: val_accuracy did not improve from 0.89844
# Epoch 26/100
# 8/8 [==============================] - 99s 13s/step - loss: 0.3315 - accuracy: 0.8398 - val_loss: 0.3002 - val_accuracy: 0.8730
#
# Epoch 00026: val_accuracy did not improve from 0.89844
# Epoch 27/100
# 8/8 [==============================] - 129s 16s/step - loss: 0.3395 - accuracy: 0.8633 - val_loss: 0.2836 - val_accuracy: 0.8848
#
# Epoch 00027: val_accuracy did not improve from 0.89844
# Epoch 28/100
# 8/8 [==============================] - 70s 9s/step - loss: 0.2862 - accuracy: 0.8867 - val_loss: 0.2920 - val_accuracy: 0.8730
#
# Epoch 00028: val_accuracy did not improve from 0.89844
# Epoch 29/100
# 8/8 [==============================] - 84s 12s/step - loss: 0.3206 - accuracy: 0.8750 - val_loss: 0.2564 - val_accuracy: 0.9082
#
# Epoch 00029: val_accuracy improved from 0.89844 to 0.90820, saving model to .\KORESmodel.h5
# Epoch 30/100
# 8/8 [==============================] - 70s 9s/step - loss: 0.3343 - accuracy: 0.8594 - val_loss: 0.2008 - val_accuracy: 0.9297
#
# Epoch 00030: val_accuracy improved from 0.90820 to 0.92969, saving model to .\KORESmodel.h5
# Epoch 31/100
# 8/8 [==============================] - 68s 9s/step - loss: 0.2593 - accuracy: 0.8711 - val_loss: 0.2281 - val_accuracy: 0.9121
#
# Epoch 00031: val_accuracy did not improve from 0.92969
# Epoch 32/100
# 8/8 [==============================] - 62s 8s/step - loss: 0.2619 - accuracy: 0.8867 - val_loss: 0.2801 - val_accuracy: 0.8828
#
# Epoch 00032: val_accuracy did not improve from 0.92969
# Epoch 33/100
# 8/8 [==============================] - 60s 8s/step - loss: 0.2903 - accuracy: 0.8945 - val_loss: 0.2393 - val_accuracy: 0.9043
#
# Epoch 00033: val_accuracy did not improve from 0.92969
# Epoch 34/100
# 8/8 [==============================] - 62s 8s/step - loss: 0.3827 - accuracy: 0.8672 - val_loss: 0.2286 - val_accuracy: 0.9395
#
# Epoch 00034: val_accuracy improved from 0.92969 to 0.93945, saving model to .\KORESmodel.h5
# Epoch 35/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.2425 - accuracy: 0.9141 - val_loss: 0.2317 - val_accuracy: 0.9180
#
# Epoch 00035: val_accuracy did not improve from 0.93945
# Epoch 36/100
# 8/8 [==============================] - 50s 7s/step - loss: 0.3090 - accuracy: 0.8672 - val_loss: 0.2906 - val_accuracy: 0.8848
#
# Epoch 00036: val_accuracy did not improve from 0.93945
# Epoch 37/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.3096 - accuracy: 0.8477 - val_loss: 0.2540 - val_accuracy: 0.9160
#
# Epoch 00037: val_accuracy did not improve from 0.93945
# Epoch 38/100
# 8/8 [==============================] - 60s 8s/step - loss: 0.3398 - accuracy: 0.8555 - val_loss: 0.3459 - val_accuracy: 0.8301
#
# Epoch 00038: val_accuracy did not improve from 0.93945
# Epoch 39/100
# 8/8 [==============================] - 57s 8s/step - loss: 0.3135 - accuracy: 0.8633 - val_loss: 0.2128 - val_accuracy: 0.9180
#
# Epoch 00039: val_accuracy did not improve from 0.93945
# Epoch 40/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.2653 - accuracy: 0.9023 - val_loss: 0.2695 - val_accuracy: 0.8828
#
# Epoch 00040: val_accuracy did not improve from 0.93945
# Epoch 41/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.3763 - accuracy: 0.8359 - val_loss: 0.2541 - val_accuracy: 0.9141
#
# Epoch 00041: val_accuracy did not improve from 0.93945
# Epoch 42/100
# 8/8 [==============================] - 57s 8s/step - loss: 0.2823 - accuracy: 0.8711 - val_loss: 0.2503 - val_accuracy: 0.9023
#
# Epoch 00042: val_accuracy did not improve from 0.93945
# Epoch 43/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.2776 - accuracy: 0.8789 - val_loss: 0.2375 - val_accuracy: 0.9180
#
# Epoch 00043: val_accuracy did not improve from 0.93945
# Epoch 44/100
# 8/8 [==============================] - 54s 7s/step - loss: 0.2906 - accuracy: 0.8816 - val_loss: 0.2879 - val_accuracy: 0.8594
#
# Epoch 00044: val_accuracy did not improve from 0.93945
# Epoch 45/100
# 8/8 [==============================] - 55s 7s/step - loss: 0.3875 - accuracy: 0.8398 - val_loss: 0.2885 - val_accuracy: 0.9023
#
# Epoch 00045: val_accuracy did not improve from 0.93945
# Epoch 46/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2877 - accuracy: 0.8867 - val_loss: 0.2746 - val_accuracy: 0.8867
#
# Epoch 00046: val_accuracy did not improve from 0.93945
# Epoch 47/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.2794 - accuracy: 0.8711 - val_loss: 0.2238 - val_accuracy: 0.9082
#
# Epoch 00047: val_accuracy did not improve from 0.93945
# Epoch 48/100
# 8/8 [==============================] - 50s 7s/step - loss: 0.2553 - accuracy: 0.9258 - val_loss: 0.2405 - val_accuracy: 0.9141
#
# Epoch 00048: val_accuracy did not improve from 0.93945
# Epoch 49/100
# 8/8 [==============================] - 54s 8s/step - loss: 0.3153 - accuracy: 0.8750 - val_loss: 0.1986 - val_accuracy: 0.9199
#
# Epoch 00049: val_accuracy did not improve from 0.93945
# Epoch 50/100
# 8/8 [==============================] - 62s 9s/step - loss: 0.3097 - accuracy: 0.8828 - val_loss: 0.2129 - val_accuracy: 0.9219
#
# Epoch 00050: val_accuracy did not improve from 0.93945
# Epoch 51/100
# 8/8 [==============================] - 72s 10s/step - loss: 0.2673 - accuracy: 0.8906 - val_loss: 0.2117 - val_accuracy: 0.9141
#
# Epoch 00051: val_accuracy did not improve from 0.93945
# Epoch 52/100
# 8/8 [==============================] - 68s 9s/step - loss: 0.2649 - accuracy: 0.8672 - val_loss: 0.2117 - val_accuracy: 0.9258
#
# Epoch 00052: val_accuracy did not improve from 0.93945
# Epoch 53/100
# 8/8 [==============================] - 113s 16s/step - loss: 0.2438 - accuracy: 0.8947 - val_loss: 0.2753 - val_accuracy: 0.8789
#
# Epoch 00053: val_accuracy did not improve from 0.93945
# Epoch 54/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.3196 - accuracy: 0.8555 - val_loss: 0.2358 - val_accuracy: 0.9277
#
# Epoch 00054: val_accuracy did not improve from 0.93945
# Epoch 55/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.3338 - accuracy: 0.8359 - val_loss: 0.2651 - val_accuracy: 0.8750
#
# Epoch 00055: val_accuracy did not improve from 0.93945
# Epoch 56/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.2710 - accuracy: 0.8945 - val_loss: 0.1982 - val_accuracy: 0.9414
#
# Epoch 00056: val_accuracy improved from 0.93945 to 0.94141, saving model to .\KORESmodel.h5
# Epoch 57/100
# 8/8 [==============================] - 49s 7s/step - loss: 0.2754 - accuracy: 0.8945 - val_loss: 0.1963 - val_accuracy: 0.9375
#
# Epoch 00057: val_accuracy did not improve from 0.94141
# Epoch 58/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.2844 - accuracy: 0.8945 - val_loss: 0.2010 - val_accuracy: 0.9219
#
# Epoch 00058: val_accuracy did not improve from 0.94141
# Epoch 59/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.2480 - accuracy: 0.8867 - val_loss: 0.1854 - val_accuracy: 0.9453
#
# Epoch 00059: val_accuracy improved from 0.94141 to 0.94531, saving model to .\KORESmodel.h5
# Epoch 60/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.2363 - accuracy: 0.9062 - val_loss: 0.1743 - val_accuracy: 0.9375
#
# Epoch 00060: val_accuracy did not improve from 0.94531
# Epoch 61/100
# 8/8 [==============================] - 77s 11s/step - loss: 0.2154 - accuracy: 0.9062 - val_loss: 0.2258 - val_accuracy: 0.9023
#
# Epoch 00061: val_accuracy did not improve from 0.94531
# Epoch 62/100
# 8/8 [==============================] - 57s 8s/step - loss: 0.2762 - accuracy: 0.8867 - val_loss: 0.1821 - val_accuracy: 0.9473
#
# Epoch 00062: val_accuracy improved from 0.94531 to 0.94727, saving model to .\KORESmodel.h5
# Epoch 63/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2197 - accuracy: 0.9258 - val_loss: 0.2135 - val_accuracy: 0.8984
#
# Epoch 00063: val_accuracy did not improve from 0.94727
# Epoch 64/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.2835 - accuracy: 0.8789 - val_loss: 0.2336 - val_accuracy: 0.9082
#
# Epoch 00064: val_accuracy did not improve from 0.94727
# Epoch 65/100
# 8/8 [==============================] - 46s 6s/step - loss: 0.2432 - accuracy: 0.9023 - val_loss: 0.1841 - val_accuracy: 0.9375
#
# Epoch 00065: val_accuracy did not improve from 0.94727
# Epoch 66/100
# 8/8 [==============================] - 50s 7s/step - loss: 0.2548 - accuracy: 0.9102 - val_loss: 0.1890 - val_accuracy: 0.9375
#
# Epoch 00066: val_accuracy did not improve from 0.94727
# Epoch 67/100
# 8/8 [==============================] - 50s 7s/step - loss: 0.2938 - accuracy: 0.8867 - val_loss: 0.2291 - val_accuracy: 0.9180
#
# Epoch 00067: val_accuracy did not improve from 0.94727
# Epoch 68/100
# 8/8 [==============================] - 54s 7s/step - loss: 0.3088 - accuracy: 0.8594 - val_loss: 0.2117 - val_accuracy: 0.9219
#
# Epoch 00068: val_accuracy did not improve from 0.94727
# Epoch 69/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.3306 - accuracy: 0.8553 - val_loss: 0.2452 - val_accuracy: 0.9102
#
# Epoch 00069: val_accuracy did not improve from 0.94727
# Epoch 70/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2822 - accuracy: 0.8945 - val_loss: 0.3120 - val_accuracy: 0.8652
#
# Epoch 00070: val_accuracy did not improve from 0.94727
# Epoch 71/100
# 8/8 [==============================] - 48s 7s/step - loss: 0.3960 - accuracy: 0.8596 - val_loss: 0.3276 - val_accuracy: 0.8379
#
# Epoch 00071: val_accuracy did not improve from 0.94727
# Epoch 72/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.3735 - accuracy: 0.8516 - val_loss: 0.3020 - val_accuracy: 0.8945
#
# Epoch 00072: val_accuracy did not improve from 0.94727
# Epoch 73/100
# 8/8 [==============================] - 55s 7s/step - loss: 0.3676 - accuracy: 0.8398 - val_loss: 0.2725 - val_accuracy: 0.8984
#
# Epoch 00073: val_accuracy did not improve from 0.94727
# Epoch 74/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.3039 - accuracy: 0.8633 - val_loss: 0.2355 - val_accuracy: 0.9219
#
# Epoch 00074: val_accuracy did not improve from 0.94727
# Epoch 75/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.2956 - accuracy: 0.8867 - val_loss: 0.2014 - val_accuracy: 0.9316
#
# Epoch 00075: val_accuracy did not improve from 0.94727
# Epoch 76/100
# 8/8 [==============================] - 59s 8s/step - loss: 0.2758 - accuracy: 0.8945 - val_loss: 0.2573 - val_accuracy: 0.8906
#
# Epoch 00076: val_accuracy did not improve from 0.94727
# Epoch 77/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.2853 - accuracy: 0.8672 - val_loss: 0.2647 - val_accuracy: 0.9062
#
# Epoch 00077: val_accuracy did not improve from 0.94727
# Epoch 78/100
# 8/8 [==============================] - 42s 6s/step - loss: 0.2707 - accuracy: 0.8945 - val_loss: 0.2176 - val_accuracy: 0.9199
#
# Epoch 00078: val_accuracy did not improve from 0.94727
# Epoch 79/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.2747 - accuracy: 0.8789 - val_loss: 0.2443 - val_accuracy: 0.9004
#
# Epoch 00079: val_accuracy did not improve from 0.94727
# Epoch 80/100
# 8/8 [==============================] - 50s 7s/step - loss: 0.2004 - accuracy: 0.9297 - val_loss: 0.2040 - val_accuracy: 0.9219
#
# Epoch 00080: val_accuracy did not improve from 0.94727
# Epoch 81/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.2764 - accuracy: 0.8789 - val_loss: 0.1800 - val_accuracy: 0.9336
#
# Epoch 00081: val_accuracy did not improve from 0.94727
# Epoch 82/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.2407 - accuracy: 0.9062 - val_loss: 0.2089 - val_accuracy: 0.9277
#
# Epoch 00082: val_accuracy did not improve from 0.94727
# Epoch 83/100
# 8/8 [==============================] - 67s 9s/step - loss: 0.3105 - accuracy: 0.8828 - val_loss: 0.2269 - val_accuracy: 0.9219
#
# Epoch 00083: val_accuracy did not improve from 0.94727
# Epoch 84/100
# 8/8 [==============================] - 69s 9s/step - loss: 0.3982 - accuracy: 0.8164 - val_loss: 0.3388 - val_accuracy: 0.8242
#
# Epoch 00084: val_accuracy did not improve from 0.94727
# Epoch 85/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.3523 - accuracy: 0.8750 - val_loss: 0.2744 - val_accuracy: 0.9004
#
# Epoch 00085: val_accuracy did not improve from 0.94727
# Epoch 86/100
# 8/8 [==============================] - 72s 10s/step - loss: 0.3286 - accuracy: 0.8594 - val_loss: 0.2531 - val_accuracy: 0.9062
#
# Epoch 00086: val_accuracy did not improve from 0.94727
# Epoch 87/100
# 8/8 [==============================] - 46s 6s/step - loss: 0.3280 - accuracy: 0.8728 - val_loss: 0.2605 - val_accuracy: 0.8867
#
# Epoch 00087: val_accuracy did not improve from 0.94727
# Epoch 88/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.3497 - accuracy: 0.8672 - val_loss: 0.2620 - val_accuracy: 0.9180
#
# Epoch 00088: val_accuracy did not improve from 0.94727
# Epoch 89/100
# 8/8 [==============================] - 57s 8s/step - loss: 0.3104 - accuracy: 0.8867 - val_loss: 0.2785 - val_accuracy: 0.8848
#
# Epoch 00089: val_accuracy did not improve from 0.94727
# Epoch 90/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.3328 - accuracy: 0.8711 - val_loss: 0.2571 - val_accuracy: 0.9023
#
# Epoch 00090: val_accuracy did not improve from 0.94727
# Epoch 91/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.3189 - accuracy: 0.8789 - val_loss: 0.2405 - val_accuracy: 0.9121
#
# Epoch 00091: val_accuracy did not improve from 0.94727
# Epoch 92/100
# 8/8 [==============================] - 54s 7s/step - loss: 0.2620 - accuracy: 0.8947 - val_loss: 0.2459 - val_accuracy: 0.9180
#
# Epoch 00092: val_accuracy did not improve from 0.94727
# Epoch 93/100
# 8/8 [==============================] - 77s 10s/step - loss: 0.2664 - accuracy: 0.8945 - val_loss: 0.2034 - val_accuracy: 0.9297
#
# Epoch 00093: val_accuracy did not improve from 0.94727
# Epoch 94/100
# 8/8 [==============================] - 64s 9s/step - loss: 0.3384 - accuracy: 0.8672 - val_loss: 0.3085 - val_accuracy: 0.8750
#
# Epoch 00094: val_accuracy did not improve from 0.94727
# Epoch 95/100
# 8/8 [==============================] - 57s 8s/step - loss: 0.3012 - accuracy: 0.8789 - val_loss: 0.2413 - val_accuracy: 0.9023
#
# Epoch 00095: val_accuracy did not improve from 0.94727
# Epoch 96/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.2751 - accuracy: 0.8945 - val_loss: 0.2470 - val_accuracy: 0.9102
#
# Epoch 00096: val_accuracy did not improve from 0.94727
# Epoch 97/100
# 8/8 [==============================] - 60s 8s/step - loss: 0.2521 - accuracy: 0.9023 - val_loss: 0.2240 - val_accuracy: 0.8984
#
# Epoch 00097: val_accuracy did not improve from 0.94727
# Epoch 98/100
# 8/8 [==============================] - 60s 8s/step - loss: 0.2935 - accuracy: 0.8789 - val_loss: 0.2269 - val_accuracy: 0.9160
#
# Epoch 00098: val_accuracy did not improve from 0.94727
# Epoch 99/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.3160 - accuracy: 0.8867 - val_loss: 0.2186 - val_accuracy: 0.9160
#
# Epoch 00099: val_accuracy did not improve from 0.94727
# Epoch 100/100
# 8/8 [==============================] - 55s 8s/step - loss: 0.2591 - accuracy: 0.9062 - val_loss: 0.2667 - val_accuracy: 0.8848
#
# Epoch 00100: val_accuracy did not improve from 0.94727

# %%
h = hs.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'])

plt.title("acc vs val-acc")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(h['loss'])
plt.plot(h['val_loss'], c= "red")

plt.title("loss vs val-loss")
plt.show()

# %%
  # model accuracy

from keras.models import load_model

model = load_model("C:\\Users\\yuvra\\pyton project\\Untitled Folder\\KORESmodel.h5")

# %%
acc = model.evaluate_generator(test_data)[1]

print(f"the accuracy of our model is {acc*100} % ")
# Out:
# the accuracy of our model is 87.714284658432 %

# %%
from keras.preprocessing.image import load_img, img_to_array

# %%
path="F:\\New Dataset - Copy\\val\\TB\\CHNCXR_0379_1.png"

img = load_img(path, target_size = (50,50))
input_arr = img_to_array(img)/255

input_arr.shape
# Out:
# (50, 50, 3)

# %%
input_arr = np.expand_dims(input_arr, axis= 0 )

# %%
pred1=(model.predict(input_arr))
a= 1-pred1

if (a<pred1):
  print("the image is infected")
else:
  print("the image is healthy")
# Out:
# the image is infected

# %%
  # to display image

plt.imshow(input_arr[0])
plt.title("input image")
plt.show()

# %%
print (pred1)
print("pred is ",pred1)
a= 1-pred1

if (a<pred1):
  print("the image is infected")
else:
  print("the image is healthy")
# Out:
# [[0.93179023]]
# pred is  [[0.93179023]]
# the image is infected

# %%
os.chdir("F:\\New Dataset - Copy\\Test\\TB\\")

# %%
arr=[]
path1=os.listdir()
path1=(path1)
l=len(path1)
print(path1[2])
# Out:
# CHNCXR_0336_1 - Copy.png

# %%
for i in range(0,l):
    path="F:\\New Dataset - Copy\\Test\\TB\\"+path1[i]

    img = load_img(path, target_size = (50,50))
    input_arr = img_to_array(img)/255

    input_arr.shape
    input_arr = np.expand_dims(input_arr, axis= 0 )
    
    pred1=(model.predict(input_arr))
    a= 1-pred1

    if (a<pred1):
      print("Infected")
    else:
      print("Healthy")

    i+1
# Out:
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected

# %%
os.chdir("F:\\New Dataset - Copy\\Test\\Normal\\")

# %%
arr=[]
path1=os.listdir()
path1=(path1)
l=len(path1)
print(path1[2])
# Out:
# Normal-1010.png

# %%
for i in range(0,l):
    path="F:\\New Dataset - Copy\\Test\\Normal\\"+path1[i]

    img = load_img(path, target_size = (50,50))
    input_arr = img_to_array(img)/255

    input_arr.shape
    input_arr = np.expand_dims(input_arr, axis= 0 )
    
    pred1=(model.predict(input_arr))
    a= 1-pred1

    if (a<pred1):
      print("Infected")
    else:
      print("Healthy")

    i+1
# Out:
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Healthy
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Infected
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Infected

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import classification_report

# %%
Model_pred=pd.read_excel("C:\\Users\\yuvra\\Documents\\32 Batch size and 100 epoch CSV file.xlsx")

# %%
confusion_M1 = pd.crosstab(Model_pred.PREDICTION_CLASS,Model_pred.ACTUAL_CLASS)

# %%
fig = plt.figure(figsize=(17,5))
ax1 = plt.subplot(121)
sn.heatmap(confusion_M1,annot=True,cmap='Blues')
ax1.set_title("Model1")
# Out:
# Text(0.5, 1.0, 'Model1')

# %%
for i in range(confusion_M1.shape[0]):
    TP = confusion_M1.iloc[i,i]
    FP = confusion_M1.iloc[i,:].sum()-TP
    FN = confusion_M1.iloc[:,i].sum()-TP
    TN=confusion_M1.sum().sum()-TP-FP-FN
    Accuracy =(TP+TN)/confusion_M1.sum().sum()
    Precision=TP/(TP+FP)
    Recall=TP/(TP+FN)
    F1_Score =(2 * Precision * Recall)/(Precision+Recall)
    
    print(confusion_M1.index[i],Accuracy,Precision,Recall,F1_Score)
# Out:
# Healthy 0.8771428571428571 0.8822393822393823 0.8704761904761905 0.8763183125599234
# Infected 0.8771428571428571 0.8721804511278195 0.8838095238095238 0.8779564806054873
