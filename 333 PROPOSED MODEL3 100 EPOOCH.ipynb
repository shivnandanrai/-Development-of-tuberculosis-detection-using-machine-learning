# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
import os 
import math 
import shutil
import glob

# %%
#count the number of images in the respective classes
ROOT_DIR = "F:/New Dataset - Copy"
number_of_images ={}
for dir in os.listdir(ROOT_DIR):
  number_of_images[dir] =len(os.listdir(os.path.join(ROOT_DIR,dir)))
number_of_images.items()
# Out:
# dict_items([('Test', 2), ('train', 2), ('val', 2)])

# %%
import keras
import tensorflow
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import tensorflow as tf
from tensorflow import keras
from keras.layers import Conv2D, Dropout,Flatten, Dense, BatchNormalization,GlobalAvgPool2D
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator

# %%
## CNN MODEL

model = Sequential()

model.add(Conv2D(filters= 16 , kernel_size= (3,3), activation='relu', input_shape = (50,50,3) ) )
model.add(Conv2D(filters= 36 , kernel_size=(3,3) , activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters= 64 , kernel_size=(3,3) , activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate= 0.25))

model.add(Flatten())
model.add(Dense(units=128 , activation= 'relu'))
model.add(Dropout(rate= 0.25))
model.add(Dense(units= 1,activation= 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 16)        448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 36)        5220
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 36)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        20800
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               819328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 845,925
# Trainable params: 845,925
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer= 'adam', loss= keras.losses.binary_crossentropy, metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint

mc= ModelCheckpoint(monitor="val_accuracy",filepath="./STORYmodel.h5", verbose= 1 , save_best_only= True , mode= 'auto' )

cd= [mc]

# %%
def preprocessingImages1(path):
#input :: path
#output : pre processed images'''

  image_data =ImageDataGenerator(zoom_range=0.2,shear_range=0.2,rescale=1/255,horizontal_flip=True)
  image = image_data.flow_from_directory(directory=path,target_size=(50,50),batch_size=32,class_mode='binary')
  return image

# %%
path="F:\\New Dataset - Copy\\train"
train_data = preprocessingImages1(path)
# Out:
# Found 4900 images belonging to 2 classes.

# %%
def preprocessingImages2(path):
#input :: path
#output : pre processed images'''

  image_data =ImageDataGenerator(rescale= 1/255)
  image = image_data.flow_from_directory(directory=path,target_size=(50,50),batch_size=32,class_mode='binary')
  return image

# %%
path="F:\\New Dataset - Copy\\Test"
test_data=preprocessingImages2(path)
# Out:
# Found 1050 images belonging to 2 classes.

# %%
path="F:\\New Dataset - Copy\\val"
val_data=preprocessingImages2(path)
# Out:
# Found 1050 images belonging to 2 classes.

# %%
hs = model.fit(train_data,
                steps_per_epoch=8 ,
                 epochs=100 ,
                  verbose= 1,
                    validation_data= val_data,
                        validation_steps= 16 ,
                         callbacks= cd)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 92s 13s/step - loss: 0.6795 - accuracy: 0.5312 - val_loss: 0.6424 - val_accuracy: 0.6953
#
# Epoch 00001: val_accuracy improved from -inf to 0.69531, saving model to .\STORYmodel.h5
# Epoch 2/100
# 8/8 [==============================] - 119s 16s/step - loss: 0.6183 - accuracy: 0.7070 - val_loss: 0.5694 - val_accuracy: 0.6934
#
# Epoch 00002: val_accuracy did not improve from 0.69531
# Epoch 3/100
# 8/8 [==============================] - 100s 14s/step - loss: 0.5505 - accuracy: 0.7031 - val_loss: 0.4562 - val_accuracy: 0.7891
#
# Epoch 00003: val_accuracy improved from 0.69531 to 0.78906, saving model to .\STORYmodel.h5
# Epoch 4/100
# 8/8 [==============================] - 82s 11s/step - loss: 0.4959 - accuracy: 0.7734 - val_loss: 0.4082 - val_accuracy: 0.8477
#
# Epoch 00004: val_accuracy improved from 0.78906 to 0.84766, saving model to .\STORYmodel.h5
# Epoch 5/100
# 8/8 [==============================] - 73s 10s/step - loss: 0.5615 - accuracy: 0.7105 - val_loss: 0.5707 - val_accuracy: 0.6621
#
# Epoch 00005: val_accuracy did not improve from 0.84766
# Epoch 6/100
# 8/8 [==============================] - 72s 10s/step - loss: 0.5181 - accuracy: 0.7266 - val_loss: 0.3925 - val_accuracy: 0.8340
#
# Epoch 00006: val_accuracy did not improve from 0.84766
# Epoch 7/100
# 8/8 [==============================] - 79s 11s/step - loss: 0.4232 - accuracy: 0.8281 - val_loss: 0.3484 - val_accuracy: 0.8477
#
# Epoch 00007: val_accuracy did not improve from 0.84766
# Epoch 8/100
# 8/8 [==============================] - 81s 12s/step - loss: 0.4194 - accuracy: 0.8070 - val_loss: 0.3287 - val_accuracy: 0.8613
#
# Epoch 00008: val_accuracy improved from 0.84766 to 0.86133, saving model to .\STORYmodel.h5
# Epoch 9/100
# 8/8 [==============================] - 138s 19s/step - loss: 0.4107 - accuracy: 0.8242 - val_loss: 0.3475 - val_accuracy: 0.8359
#
# Epoch 00009: val_accuracy did not improve from 0.86133
# Epoch 10/100
# 8/8 [==============================] - 105s 14s/step - loss: 0.3893 - accuracy: 0.8202 - val_loss: 0.3624 - val_accuracy: 0.8418
#
# Epoch 00010: val_accuracy did not improve from 0.86133
# Epoch 11/100
# 8/8 [==============================] - 113s 16s/step - loss: 0.3928 - accuracy: 0.8203 - val_loss: 0.3429 - val_accuracy: 0.8750
#
# Epoch 00011: val_accuracy improved from 0.86133 to 0.87500, saving model to .\STORYmodel.h5
# Epoch 12/100
# 8/8 [==============================] - 139s 19s/step - loss: 0.3859 - accuracy: 0.8555 - val_loss: 0.2777 - val_accuracy: 0.8848
#
# Epoch 00012: val_accuracy improved from 0.87500 to 0.88477, saving model to .\STORYmodel.h5
# Epoch 13/100
# 8/8 [==============================] - 112s 15s/step - loss: 0.3940 - accuracy: 0.8281 - val_loss: 0.3441 - val_accuracy: 0.8457
#
# Epoch 00013: val_accuracy did not improve from 0.88477
# Epoch 14/100
# 8/8 [==============================] - 102s 14s/step - loss: 0.3039 - accuracy: 0.8789 - val_loss: 0.2825 - val_accuracy: 0.8867
#
# Epoch 00014: val_accuracy improved from 0.88477 to 0.88672, saving model to .\STORYmodel.h5
# Epoch 15/100
# 8/8 [==============================] - 88s 12s/step - loss: 0.3344 - accuracy: 0.8711 - val_loss: 0.3106 - val_accuracy: 0.8613
#
# Epoch 00015: val_accuracy did not improve from 0.88672
# Epoch 16/100
# 8/8 [==============================] - 73s 10s/step - loss: 0.3028 - accuracy: 0.8750 - val_loss: 0.2757 - val_accuracy: 0.8730
#
# Epoch 00016: val_accuracy did not improve from 0.88672
# Epoch 17/100
# 8/8 [==============================] - 131s 18s/step - loss: 0.3291 - accuracy: 0.8594 - val_loss: 0.3051 - val_accuracy: 0.8652
#
# Epoch 00017: val_accuracy did not improve from 0.88672
# Epoch 18/100
# 8/8 [==============================] - 98s 13s/step - loss: 0.3162 - accuracy: 0.8516 - val_loss: 0.2889 - val_accuracy: 0.8574
#
# Epoch 00018: val_accuracy did not improve from 0.88672
# Epoch 19/100
# 8/8 [==============================] - 195s 27s/step - loss: 0.3299 - accuracy: 0.8516 - val_loss: 0.2459 - val_accuracy: 0.9141
#
# Epoch 00019: val_accuracy improved from 0.88672 to 0.91406, saving model to .\STORYmodel.h5
# Epoch 20/100
# 8/8 [==============================] - 176s 24s/step - loss: 0.3009 - accuracy: 0.8789 - val_loss: 0.2314 - val_accuracy: 0.9160
#
# Epoch 00020: val_accuracy improved from 0.91406 to 0.91602, saving model to .\STORYmodel.h5
# Epoch 21/100
# 8/8 [==============================] - 201s 26s/step - loss: 0.2475 - accuracy: 0.8945 - val_loss: 0.2438 - val_accuracy: 0.8984
#
# Epoch 00021: val_accuracy did not improve from 0.91602
# Epoch 22/100
# 8/8 [==============================] - 131s 18s/step - loss: 0.3238 - accuracy: 0.8789 - val_loss: 0.3412 - val_accuracy: 0.8301
#
# Epoch 00022: val_accuracy did not improve from 0.91602
# Epoch 23/100
# 8/8 [==============================] - 139s 18s/step - loss: 0.3349 - accuracy: 0.8594 - val_loss: 0.2465 - val_accuracy: 0.8926
#
# Epoch 00023: val_accuracy did not improve from 0.91602
# Epoch 24/100
# 8/8 [==============================] - 100s 14s/step - loss: 0.2828 - accuracy: 0.8789 - val_loss: 0.2240 - val_accuracy: 0.9180
#
# Epoch 00024: val_accuracy improved from 0.91602 to 0.91797, saving model to .\STORYmodel.h5
# Epoch 25/100
# 8/8 [==============================] - 132s 17s/step - loss: 0.2750 - accuracy: 0.8906 - val_loss: 0.2611 - val_accuracy: 0.8926
#
# Epoch 00025: val_accuracy did not improve from 0.91797
# Epoch 26/100
# 8/8 [==============================] - 122s 17s/step - loss: 0.3130 - accuracy: 0.8750 - val_loss: 0.3250 - val_accuracy: 0.8613
#
# Epoch 00026: val_accuracy did not improve from 0.91797
# Epoch 27/100
# 8/8 [==============================] - 111s 15s/step - loss: 0.3138 - accuracy: 0.8555 - val_loss: 0.2785 - val_accuracy: 0.8828
#
# Epoch 00027: val_accuracy did not improve from 0.91797
# Epoch 28/100
# 8/8 [==============================] - 95s 13s/step - loss: 0.3088 - accuracy: 0.8672 - val_loss: 0.2745 - val_accuracy: 0.8691
#
# Epoch 00028: val_accuracy did not improve from 0.91797
# Epoch 29/100
# 8/8 [==============================] - 93s 13s/step - loss: 0.2473 - accuracy: 0.9141 - val_loss: 0.2335 - val_accuracy: 0.9219
#
# Epoch 00029: val_accuracy improved from 0.91797 to 0.92188, saving model to .\STORYmodel.h5
# Epoch 30/100
# 8/8 [==============================] - 104s 14s/step - loss: 0.2214 - accuracy: 0.9062 - val_loss: 0.2134 - val_accuracy: 0.9102
#
# Epoch 00030: val_accuracy did not improve from 0.92188
# Epoch 31/100
# 8/8 [==============================] - 93s 13s/step - loss: 0.3163 - accuracy: 0.8789 - val_loss: 0.2260 - val_accuracy: 0.8984
#
# Epoch 00031: val_accuracy did not improve from 0.92188
# Epoch 32/100
# 8/8 [==============================] - 87s 12s/step - loss: 0.3134 - accuracy: 0.8789 - val_loss: 0.2347 - val_accuracy: 0.9043
#
# Epoch 00032: val_accuracy did not improve from 0.92188
# Epoch 33/100
# 8/8 [==============================] - 109s 15s/step - loss: 0.2412 - accuracy: 0.9102 - val_loss: 0.2211 - val_accuracy: 0.9297
#
# Epoch 00033: val_accuracy improved from 0.92188 to 0.92969, saving model to .\STORYmodel.h5
# Epoch 34/100
# 8/8 [==============================] - 83s 11s/step - loss: 0.3047 - accuracy: 0.9023 - val_loss: 0.2249 - val_accuracy: 0.9062
#
# Epoch 00034: val_accuracy did not improve from 0.92969
# Epoch 35/100
# 8/8 [==============================] - 69s 9s/step - loss: 0.3008 - accuracy: 0.8750 - val_loss: 0.2331 - val_accuracy: 0.9121
#
# Epoch 00035: val_accuracy did not improve from 0.92969
# Epoch 36/100
# 8/8 [==============================] - 62s 8s/step - loss: 0.2964 - accuracy: 0.8945 - val_loss: 0.2059 - val_accuracy: 0.9336
#
# Epoch 00036: val_accuracy improved from 0.92969 to 0.93359, saving model to .\STORYmodel.h5
# Epoch 37/100
# 8/8 [==============================] - 78s 11s/step - loss: 0.2244 - accuracy: 0.9180 - val_loss: 0.2318 - val_accuracy: 0.8965
#
# Epoch 00037: val_accuracy did not improve from 0.93359
# Epoch 38/100
# 8/8 [==============================] - 101s 13s/step - loss: 0.3093 - accuracy: 0.8828 - val_loss: 0.2182 - val_accuracy: 0.9219
#
# Epoch 00038: val_accuracy did not improve from 0.93359
# Epoch 39/100
# 8/8 [==============================] - 75s 10s/step - loss: 0.2577 - accuracy: 0.9023 - val_loss: 0.2280 - val_accuracy: 0.8945
#
# Epoch 00039: val_accuracy did not improve from 0.93359
# Epoch 40/100
# 8/8 [==============================] - 74s 10s/step - loss: 0.1467 - accuracy: 0.9648 - val_loss: 0.2188 - val_accuracy: 0.9199
#
# Epoch 00040: val_accuracy did not improve from 0.93359
# Epoch 41/100
# 8/8 [==============================] - 88s 12s/step - loss: 0.2067 - accuracy: 0.9023 - val_loss: 0.1696 - val_accuracy: 0.9434
#
# Epoch 00041: val_accuracy improved from 0.93359 to 0.94336, saving model to .\STORYmodel.h5
# Epoch 42/100
# 8/8 [==============================] - 77s 10s/step - loss: 0.1750 - accuracy: 0.9492 - val_loss: 0.1643 - val_accuracy: 0.9434
#
# Epoch 00042: val_accuracy did not improve from 0.94336
# Epoch 43/100
# 8/8 [==============================] - 60s 8s/step - loss: 0.1872 - accuracy: 0.9297 - val_loss: 0.1698 - val_accuracy: 0.9297
#
# Epoch 00043: val_accuracy did not improve from 0.94336
# Epoch 44/100
# 8/8 [==============================] - 61s 8s/step - loss: 0.2324 - accuracy: 0.9023 - val_loss: 0.1731 - val_accuracy: 0.9316
#
# Epoch 00044: val_accuracy did not improve from 0.94336
# Epoch 45/100
# 8/8 [==============================] - 62s 8s/step - loss: 0.3466 - accuracy: 0.8728 - val_loss: 0.2114 - val_accuracy: 0.9434
#
# Epoch 00045: val_accuracy did not improve from 0.94336
# Epoch 46/100
# 8/8 [==============================] - 69s 9s/step - loss: 0.3307 - accuracy: 0.8711 - val_loss: 0.2700 - val_accuracy: 0.8770
#
# Epoch 00046: val_accuracy did not improve from 0.94336
# Epoch 47/100
# 8/8 [==============================] - 66s 9s/step - loss: 0.3643 - accuracy: 0.8047 - val_loss: 0.2855 - val_accuracy: 0.9199
#
# Epoch 00047: val_accuracy did not improve from 0.94336
# Epoch 48/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.2837 - accuracy: 0.9035 - val_loss: 0.3391 - val_accuracy: 0.8340
#
# Epoch 00048: val_accuracy did not improve from 0.94336
# Epoch 49/100
# 8/8 [==============================] - 64s 9s/step - loss: 0.3427 - accuracy: 0.8555 - val_loss: 0.4003 - val_accuracy: 0.8281
#
# Epoch 00049: val_accuracy did not improve from 0.94336
# Epoch 50/100
# 8/8 [==============================] - 61s 8s/step - loss: 0.2891 - accuracy: 0.8906 - val_loss: 0.2590 - val_accuracy: 0.9062
#
# Epoch 00050: val_accuracy did not improve from 0.94336
# Epoch 51/100
# 8/8 [==============================] - 64s 9s/step - loss: 0.3730 - accuracy: 0.8672 - val_loss: 0.2289 - val_accuracy: 0.9355
#
# Epoch 00051: val_accuracy did not improve from 0.94336
# Epoch 52/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.2948 - accuracy: 0.8711 - val_loss: 0.2270 - val_accuracy: 0.9141
#
# Epoch 00052: val_accuracy did not improve from 0.94336
# Epoch 53/100
# 8/8 [==============================] - 59s 8s/step - loss: 0.2793 - accuracy: 0.8906 - val_loss: 0.2522 - val_accuracy: 0.8770
#
# Epoch 00053: val_accuracy did not improve from 0.94336
# Epoch 54/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.2018 - accuracy: 0.9336 - val_loss: 0.1785 - val_accuracy: 0.9355
#
# Epoch 00054: val_accuracy did not improve from 0.94336
# Epoch 55/100
# 8/8 [==============================] - 58s 8s/step - loss: 0.2514 - accuracy: 0.8984 - val_loss: 0.2252 - val_accuracy: 0.9121
#
# Epoch 00055: val_accuracy did not improve from 0.94336
# Epoch 56/100
# 8/8 [==============================] - 57s 8s/step - loss: 0.2872 - accuracy: 0.8594 - val_loss: 0.2322 - val_accuracy: 0.9258
#
# Epoch 00056: val_accuracy did not improve from 0.94336
# Epoch 57/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2413 - accuracy: 0.8906 - val_loss: 0.2526 - val_accuracy: 0.8926
#
# Epoch 00057: val_accuracy did not improve from 0.94336
# Epoch 58/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.2522 - accuracy: 0.9219 - val_loss: 0.1913 - val_accuracy: 0.9219
#
# Epoch 00058: val_accuracy did not improve from 0.94336
# Epoch 59/100
# 8/8 [==============================] - 48s 6s/step - loss: 0.1837 - accuracy: 0.9336 - val_loss: 0.2144 - val_accuracy: 0.9062
#
# Epoch 00059: val_accuracy did not improve from 0.94336
# Epoch 60/100
# 8/8 [==============================] - 55s 7s/step - loss: 0.2031 - accuracy: 0.9180 - val_loss: 0.2259 - val_accuracy: 0.9238
#
# Epoch 00060: val_accuracy did not improve from 0.94336
# Epoch 61/100
# 8/8 [==============================] - 59s 8s/step - loss: 0.2098 - accuracy: 0.8984 - val_loss: 0.1673 - val_accuracy: 0.9492
#
# Epoch 00061: val_accuracy improved from 0.94336 to 0.94922, saving model to .\STORYmodel.h5
# Epoch 62/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2207 - accuracy: 0.9180 - val_loss: 0.2095 - val_accuracy: 0.9160
#
# Epoch 00062: val_accuracy did not improve from 0.94922
# Epoch 63/100
# 8/8 [==============================] - 59s 8s/step - loss: 0.2158 - accuracy: 0.9141 - val_loss: 0.1818 - val_accuracy: 0.9395
#
# Epoch 00063: val_accuracy did not improve from 0.94922
# Epoch 64/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.2159 - accuracy: 0.9102 - val_loss: 0.1903 - val_accuracy: 0.9355
#
# Epoch 00064: val_accuracy did not improve from 0.94922
# Epoch 65/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.2306 - accuracy: 0.9079 - val_loss: 0.2001 - val_accuracy: 0.9199
#
# Epoch 00065: val_accuracy did not improve from 0.94922
# Epoch 66/100
# 8/8 [==============================] - 55s 7s/step - loss: 0.2419 - accuracy: 0.8945 - val_loss: 0.1748 - val_accuracy: 0.9512
#
# Epoch 00066: val_accuracy improved from 0.94922 to 0.95117, saving model to .\STORYmodel.h5
# Epoch 67/100
# 8/8 [==============================] - 75s 10s/step - loss: 0.2220 - accuracy: 0.9141 - val_loss: 0.2371 - val_accuracy: 0.8926
#
# Epoch 00067: val_accuracy did not improve from 0.95117
# Epoch 68/100
# 8/8 [==============================] - 62s 8s/step - loss: 0.2639 - accuracy: 0.8906 - val_loss: 0.1973 - val_accuracy: 0.9258
#
# Epoch 00068: val_accuracy did not improve from 0.95117
# Epoch 69/100
# 8/8 [==============================] - 57s 8s/step - loss: 0.2496 - accuracy: 0.9023 - val_loss: 0.1871 - val_accuracy: 0.9395
#
# Epoch 00069: val_accuracy did not improve from 0.95117
# Epoch 70/100
# 8/8 [==============================] - 53s 7s/step - loss: 0.2665 - accuracy: 0.8867 - val_loss: 0.1937 - val_accuracy: 0.9375
#
# Epoch 00070: val_accuracy did not improve from 0.95117
# Epoch 71/100
# 8/8 [==============================] - 54s 7s/step - loss: 0.2712 - accuracy: 0.8867 - val_loss: 0.1785 - val_accuracy: 0.9492
#
# Epoch 00071: val_accuracy did not improve from 0.95117
# Epoch 72/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.2059 - accuracy: 0.9062 - val_loss: 0.1915 - val_accuracy: 0.9258
#
# Epoch 00072: val_accuracy did not improve from 0.95117
# Epoch 73/100
# 8/8 [==============================] - 49s 7s/step - loss: 0.2019 - accuracy: 0.9298 - val_loss: 0.1991 - val_accuracy: 0.9180
#
# Epoch 00073: val_accuracy did not improve from 0.95117
# Epoch 74/100
# 8/8 [==============================] - 69s 10s/step - loss: 0.2405 - accuracy: 0.9102 - val_loss: 0.2436 - val_accuracy: 0.8984
#
# Epoch 00074: val_accuracy did not improve from 0.95117
# Epoch 75/100
# 8/8 [==============================] - 66s 9s/step - loss: 0.1965 - accuracy: 0.9180 - val_loss: 0.1849 - val_accuracy: 0.9434
#
# Epoch 00075: val_accuracy did not improve from 0.95117
# Epoch 76/100
# 8/8 [==============================] - 75s 10s/step - loss: 0.2524 - accuracy: 0.8984 - val_loss: 0.1912 - val_accuracy: 0.9297
#
# Epoch 00076: val_accuracy did not improve from 0.95117
# Epoch 77/100
# 8/8 [==============================] - 52s 7s/step - loss: 0.2214 - accuracy: 0.9062 - val_loss: 0.2163 - val_accuracy: 0.9121
#
# Epoch 00077: val_accuracy did not improve from 0.95117
# Epoch 78/100
# 8/8 [==============================] - 55s 8s/step - loss: 0.2052 - accuracy: 0.9102 - val_loss: 0.1804 - val_accuracy: 0.9355
#
# Epoch 00078: val_accuracy did not improve from 0.95117
# Epoch 79/100
# 8/8 [==============================] - 60s 8s/step - loss: 0.2606 - accuracy: 0.8945 - val_loss: 0.2044 - val_accuracy: 0.9102
#
# Epoch 00079: val_accuracy did not improve from 0.95117
# Epoch 80/100
# 8/8 [==============================] - 99s 14s/step - loss: 0.2535 - accuracy: 0.8828 - val_loss: 0.1844 - val_accuracy: 0.9180
#
# Epoch 00080: val_accuracy did not improve from 0.95117
# Epoch 81/100
# 8/8 [==============================] - 101s 14s/step - loss: 0.2962 - accuracy: 0.8984 - val_loss: 0.4010 - val_accuracy: 0.8047
#
# Epoch 00081: val_accuracy did not improve from 0.95117
# Epoch 82/100
# 8/8 [==============================] - 85s 12s/step - loss: 0.2770 - accuracy: 0.9079 - val_loss: 0.2808 - val_accuracy: 0.8926
#
# Epoch 00082: val_accuracy did not improve from 0.95117
# Epoch 83/100
# 8/8 [==============================] - 72s 10s/step - loss: 0.2725 - accuracy: 0.8828 - val_loss: 0.2661 - val_accuracy: 0.8965
#
# Epoch 00083: val_accuracy did not improve from 0.95117
# Epoch 84/100
# 8/8 [==============================] - 79s 11s/step - loss: 0.2939 - accuracy: 0.8984 - val_loss: 0.2399 - val_accuracy: 0.9141
#
# Epoch 00084: val_accuracy did not improve from 0.95117
# Epoch 85/100
# 8/8 [==============================] - 51s 7s/step - loss: 0.2634 - accuracy: 0.9062 - val_loss: 0.1921 - val_accuracy: 0.9375
#
# Epoch 00085: val_accuracy did not improve from 0.95117
# Epoch 86/100
# 8/8 [==============================] - 61s 8s/step - loss: 0.2079 - accuracy: 0.9180 - val_loss: 0.1784 - val_accuracy: 0.9492
#
# Epoch 00086: val_accuracy did not improve from 0.95117
# Epoch 87/100
# 8/8 [==============================] - 55s 7s/step - loss: 0.2028 - accuracy: 0.9180 - val_loss: 0.1984 - val_accuracy: 0.9414
#
# Epoch 00087: val_accuracy did not improve from 0.95117
# Epoch 88/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2376 - accuracy: 0.9062 - val_loss: 0.2106 - val_accuracy: 0.9102
#
# Epoch 00088: val_accuracy did not improve from 0.95117
# Epoch 89/100
# 8/8 [==============================] - 65s 9s/step - loss: 0.2189 - accuracy: 0.9062 - val_loss: 0.1788 - val_accuracy: 0.9336
#
# Epoch 00089: val_accuracy did not improve from 0.95117
# Epoch 90/100
# 8/8 [==============================] - 86s 12s/step - loss: 0.2414 - accuracy: 0.8906 - val_loss: 0.2170 - val_accuracy: 0.8887
#
# Epoch 00090: val_accuracy did not improve from 0.95117
# Epoch 91/100
# 8/8 [==============================] - 80s 11s/step - loss: 0.2593 - accuracy: 0.8867 - val_loss: 0.1712 - val_accuracy: 0.9453
#
# Epoch 00091: val_accuracy did not improve from 0.95117
# Epoch 92/100
# 8/8 [==============================] - 66s 9s/step - loss: 0.2222 - accuracy: 0.9102 - val_loss: 0.1681 - val_accuracy: 0.9570
#
# Epoch 00092: val_accuracy improved from 0.95117 to 0.95703, saving model to .\STORYmodel.h5
# Epoch 93/100
# 8/8 [==============================] - 76s 10s/step - loss: 0.1715 - accuracy: 0.9531 - val_loss: 0.2072 - val_accuracy: 0.9238
#
# Epoch 00093: val_accuracy did not improve from 0.95703
# Epoch 94/100
# 8/8 [==============================] - 68s 9s/step - loss: 0.2464 - accuracy: 0.8984 - val_loss: 0.2130 - val_accuracy: 0.9082
#
# Epoch 00094: val_accuracy did not improve from 0.95703
# Epoch 95/100
# 8/8 [==============================] - 85s 12s/step - loss: 0.2206 - accuracy: 0.9102 - val_loss: 0.2163 - val_accuracy: 0.8945
#
# Epoch 00095: val_accuracy did not improve from 0.95703
# Epoch 96/100
# 8/8 [==============================] - 63s 9s/step - loss: 0.3061 - accuracy: 0.8750 - val_loss: 0.1734 - val_accuracy: 0.9375
#
# Epoch 00096: val_accuracy did not improve from 0.95703
# Epoch 97/100
# 8/8 [==============================] - 83s 11s/step - loss: 0.2922 - accuracy: 0.8477 - val_loss: 0.2244 - val_accuracy: 0.9199
#
# Epoch 00097: val_accuracy did not improve from 0.95703
# Epoch 98/100
# 8/8 [==============================] - 65s 9s/step - loss: 0.2190 - accuracy: 0.9180 - val_loss: 0.2478 - val_accuracy: 0.8867
#
# Epoch 00098: val_accuracy did not improve from 0.95703
# Epoch 99/100
# 8/8 [==============================] - 63s 9s/step - loss: 0.2232 - accuracy: 0.9219 - val_loss: 0.1595 - val_accuracy: 0.9512
#
# Epoch 00099: val_accuracy did not improve from 0.95703
# Epoch 100/100
# 8/8 [==============================] - 56s 8s/step - loss: 0.2901 - accuracy: 0.8789 - val_loss: 0.1982 - val_accuracy: 0.9336
#
# Epoch 00100: val_accuracy did not improve from 0.95703

# %%
h = hs.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'])

plt.title("acc vs val-acc")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(h['loss'])
plt.plot(h['val_loss'], c= "red")

plt.title("loss vs val-loss")
plt.show()

# %%
  # model accuracy

from keras.models import load_model

model = load_model("C:\\Users\\yuvra\\pyton project\\Untitled Folder\\STORYmodel.h5")

# %%
acc = model.evaluate_generator(test_data)[1]

print(f"the accuracy of our model is {acc*100} % ")
# Out:
# the accuracy of our model is 92.09523797035217 %

# %%
from keras.preprocessing.image import load_img, img_to_array

# %%
path="F:\\New Dataset - Copy\\val\\TB\\CHNCXR_0379_1.png"

img = load_img(path, target_size = (50,50))
input_arr = img_to_array(img)/255

input_arr.shape
# Out:
# (50, 50, 3)

# %%
input_arr = np.expand_dims(input_arr, axis= 0 )

# %%
pred1=(model.predict(input_arr))
a= 1-pred1

if (a<pred1):
  print("the image is infected")
else:
  print("the image is healthy")
# Out:
# the image is infected

# %%
  # to display image

plt.imshow(input_arr[0])
plt.title("input image")
plt.show()

# %%
print (pred1)
print("pred is ",pred1)
a= 1-pred1

if (a<pred1):
  print("the image is infected")
else:
  print("the image is healthy")
# Out:
# [[0.9629722]]
# pred is  [[0.9629722]]
# the image is infected

# %%
os.chdir("F:\\New Dataset - Copy\\Test\\TB\\")

# %%
arr=[]
path1=os.listdir()
path1=(path1)
l=len(path1)
print(path1[2])
# Out:
# CHNCXR_0336_1 - Copy.png

# %%
for i in range(0,l):
    path="F:\\New Dataset - Copy\\Test\\TB\\"+path1[i]

    img = load_img(path, target_size = (50,50))
    input_arr = img_to_array(img)/255

    input_arr.shape
    input_arr = np.expand_dims(input_arr, axis= 0 )
    
    pred1=(model.predict(input_arr))
    a= 1-pred1

    if (a<pred1):
      print("Infected")
    else:
      print("Healthy")

    i+1
# Out:
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected
# Infected

# %%
os.chdir("F:\\New Dataset - Copy\\Test\\Normal\\")

# %%
arr=[]
path1=os.listdir()
path1=(path1)
l=len(path1)
print(path1[2])
# Out:
# Normal-1010.png

# %%
for i in range(0,l):
    path="F:\\New Dataset - Copy\\Test\\Normal\\"+path1[i]

    img = load_img(path, target_size = (50,50))
    input_arr = img_to_array(img)/255

    input_arr.shape
    input_arr = np.expand_dims(input_arr, axis= 0 )
    
    pred1=(model.predict(input_arr))
    a= 1-pred1

    if (a<pred1):
      print("Infected")
    else:
      print("Healthy")

    i+1
# Out:
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected
# Infected
# Healthy
# Infected
# Healthy
# Healthy
# Healthy
# Healthy
# Healthy
# Infected

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import classification_report

# %%
Model_pred=pd.read_excel("C:\\Users\\yuvra\\Documents\\333 prosoed model3 CSV File.xlsx")

# %%
confusion_M1 = pd.crosstab(Model_pred.PREDICTION_CLASS,Model_pred.ACTUAL_CLASS)

# %%
fig = plt.figure(figsize=(17,5))
ax1 = plt.subplot(121)
sn.heatmap(confusion_M1,annot=True,cmap='Blues')
ax1.set_title("Model1")
# Out:
# Text(0.5, 1.0, 'Model1')

# %%
for i in range(confusion_M1.shape[0]):
    TP = confusion_M1.iloc[i,i]
    FP = confusion_M1.iloc[i,:].sum()-TP
    FN = confusion_M1.iloc[:,i].sum()-TP
    TN=confusion_M1.sum().sum()-TP-FP-FN
    Accuracy =(TP+TN)/confusion_M1.sum().sum()
    Precision=TP/(TP+FP)
    Recall=TP/(TP+FN)
    F1_Score =(2 * Precision * Recall)/(Precision+Recall)
    
    print(confusion_M1.index[i],Accuracy,Precision,Recall,F1_Score)
# Out:
# Healthy 0.920952380952381 0.9217557251908397 0.92 0.9208770257387988
# Infected 0.920952380952381 0.9201520912547528 0.9219047619047619 0.9210275927687916
